# %%
# Install required packages
# !pip install streamlit tensorflow pillow
import streamlit as st
import tensorflow as tf
import numpy as np
from tensorflow.keras.preprocessing import image
from PIL import Image
import io

# Load the trained model
@st.cache_resource
def load_trained_model():
    model_path = "./breast_cancer/BreastCancerMobileNet.h5"
    model = tf.keras.models.load_model(model_path)
    return model

# Function to preprocess the uploaded image
def preprocess_input_image(img):
    img = img.resize((224, 224))  # Resize to match model input size
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = tf.keras.applications.mobilenet_v3.preprocess_input(img_array)
    return img_array

# Load model
model = load_trained_model()

# Define class names
class_names = ["class_1", "class_2", "class_3", "class_4", "class_5"]  # Update with actual class names

# Streamlit UI
st.title("Breast Cancer Classification")
st.write("Upload an image to predict its class")

uploaded_file = st.file_uploader("Choose an image...", type=["jpg", "png", "jpeg"])

if uploaded_file is not None:
    # Convert the file to an image
    image_data = Image.open(uploaded_file)
    st.image(image_data, caption="Uploaded Image", use_column_width=True)
    
    # Preprocess the image
    img_array = preprocess_input_image(image_data)
    
    # Make prediction
    predictions = model.predict(img_array)
    predicted_class_index = np.argmax(predictions[0])
    predicted_class_name = class_names[predicted_class_index]
    
    # Display the prediction
    st.write(f"### Predicted Class: {predicted_class_name}")
# Out:
# Collecting streamlit
#   Downloading streamlit-1.40.1-py2.py3-none-any.whl (8.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 6.2 MB/s eta 0:00:0000:0100:01m
# Requirement already satisfied: tensorflow in ./myenv/lib/python3.8/site-packages (2.13.0)
# Requirement already satisfied: pillow in ./myenv/lib/python3.8/site-packages (10.4.0)
# Requirement already satisfied: tornado<7,>=6.0.3 in ./myenv/lib/python3.8/site-packages (from streamlit) (6.4.2)
# Collecting pyarrow>=7.0
#   Downloading pyarrow-17.0.0-cp38-cp38-macosx_11_0_arm64.whl (27.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.2/27.2 MB 4.8 MB/s eta 0:00:0000:0100:01
# Collecting pydeck<1,>=0.8.0b4
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 5.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: cachetools<6,>=4.0 in ./myenv/lib/python3.8/site-packages (from streamlit) (5.5.2)
# Collecting rich<14,>=10.14.0
#   Using cached rich-13.9.4-py3-none-any.whl (242 kB)
# Requirement already satisfied: packaging<25,>=20 in ./myenv/lib/python3.8/site-packages (from streamlit) (24.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in ./myenv/lib/python3.8/site-packages (from streamlit) (4.5.0)
# Collecting toml<2,>=0.10.1
#   Using cached toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: protobuf<6,>=3.20 in ./myenv/lib/python3.8/site-packages (from streamlit) (4.25.6)
# Collecting gitpython!=3.1.19,<4,>=3.0.7
#   Downloading GitPython-3.1.44-py3-none-any.whl (207 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.6/207.6 kB 4.5 MB/s eta 0:00:0000:01
# Requirement already satisfied: numpy<3,>=1.20 in ./myenv/lib/python3.8/site-packages (from streamlit) (1.24.3)
# Requirement already satisfied: requests<3,>=2.27 in ./myenv/lib/python3.8/site-packages (from streamlit) (2.32.3)
# Collecting blinker<2,>=1.0.0
#   Downloading blinker-1.8.2-py3-none-any.whl (9.5 kB)
# Collecting click<9,>=7.0
#   Downloading click-8.1.8-py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 4.6 MB/s eta 0:00:00
# Collecting altair<6,>=4.0
#   Downloading altair-5.4.1-py3-none-any.whl (658 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 658.1/658.1 kB 5.6 MB/s eta 0:00:0000:0100:01
# Collecting pandas<3,>=1.4.0
#   Using cached pandas-2.0.3-cp38-cp38-macosx_11_0_arm64.whl (10.7 MB)
# Collecting tenacity<10,>=8.1.0
#   Downloading tenacity-9.0.0-py3-none-any.whl (28 kB)
# Requirement already satisfied: tensorflow-macos==2.13.0 in ./myenv/lib/python3.8/site-packages (from tensorflow) (2.13.0)
# Requirement already satisfied: h5py>=2.9.0 in ./myenv/lib/python3.8/site-packages (from tensorflow-macos==2.13.0->tensorflow) (3.11.0)
# Requirement already satisfied: flatbuffers>=23.1.21 in ./myenv/lib/python3.8/site-packages (from tensorflow-macos==2.13.0->tensorflow) (25.2.10)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in ./myenv/lib/python3.8/site-packages (from tensorflow-macos==2.13.0->tensorflow) (1.70.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in ./myenv/lib/python3.8/site-packages (from tensorflow-macos==2.13.0->tensorflow) (2.13.1)
# Requirement already satisfied: wrapt>=1.11.0 in ./myenv/lib/python3.8/site-packages (from tensorflow-macos==2.13.0->tensorflow) (1.17.2)
# Requirement already satisfied: termcolor>=1.1.0 in ./myenv/lib/python3.8/site-packages (from tensorflow-macos==2.13.0->tensorflow) (2.4.0)
# Requirement already satisfied: libclang>=13.0.0 in ./myenv/lib/python3.8/site-packages (from tensorflow-macos==2.13.0->tensorflow) (18.1.1)
# Requirement already satisfied: six>=1.12.0 in ./myenv/lib/python3.8/site-packages (from tensorflow-macos==2.13.0->tensorflow) (1.17.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in ./myenv/lib/python3.8/site-packages (from tensorflow-macos==2.13.0->tensorflow) (2.13.0)
# Requirement already satisfied: google-pasta>=0.1.1 in ./myenv/lib/python3.8/site-packages (from tensorflow-macos==2.13.0->tensorflow) (0.2.0)
# Requirement already satisfied: setuptools in ./myenv/lib/python3.8/site-packages (from tensorflow-macos==2.13.0->tensorflow) (56.0.0)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in ./myenv/lib/python3.8/site-packages (from tensorflow-macos==2.13.0->tensorflow) (2.13.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in ./myenv/lib/python3.8/site-packages (from tensorflow-macos==2.13.0->tensorflow) (3.4.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in ./myenv/lib/python3.8/site-packages (from tensorflow-macos==2.13.0->tensorflow) (0.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in ./myenv/lib/python3.8/site-packages (from tensorflow-macos==2.13.0->tensorflow) (1.6.3)
# Requirement already satisfied: absl-py>=1.0.0 in ./myenv/lib/python3.8/site-packages (from tensorflow-macos==2.13.0->tensorflow) (2.1.0)
# Collecting jsonschema>=3.0
#   Downloading jsonschema-4.23.0-py3-none-any.whl (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.5/88.5 kB 5.3 MB/s eta 0:00:00
# Collecting jinja2
#   Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.9/134.9 kB 5.9 MB/s eta 0:00:00
# Collecting narwhals>=1.5.2
#   Downloading narwhals-1.30.0-py3-none-any.whl (313 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 6.7 MB/s eta 0:00:0000:01
# Collecting altair<6,>=4.0
#   Downloading altair-5.4.0-py3-none-any.whl (671 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 671.7/671.7 kB 7.1 MB/s eta 0:00:00a 0:00:01
#   Downloading altair-5.3.0-py3-none-any.whl (857 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 857.8/857.8 kB 8.2 MB/s eta 0:00:00a 0:00:01
# Collecting toolz
#   Using cached toolz-1.0.0-py3-none-any.whl (56 kB)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 5.1 MB/s eta 0:00:00
# Collecting pytz>=2020.1
#   Downloading pytz-2025.1-py2.py3-none-any.whl (507 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.9/507.9 kB 8.5 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: python-dateutil>=2.8.2 in ./myenv/lib/python3.8/site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Collecting tzdata>=2022.1
#   Downloading tzdata-2025.1-py2.py3-none-any.whl (346 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.8/346.8 kB 7.9 MB/s eta 0:00:0000:01
# Requirement already satisfied: idna<4,>=2.5 in ./myenv/lib/python3.8/site-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./myenv/lib/python3.8/site-packages (from requests<3,>=2.27->streamlit) (3.4.1)
# Requirement already satisfied: certifi>=2017.4.17 in ./myenv/lib/python3.8/site-packages (from requests<3,>=2.27->streamlit) (2025.1.31)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./myenv/lib/python3.8/site-packages (from requests<3,>=2.27->streamlit) (2.2.3)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./myenv/lib/python3.8/site-packages (from rich<14,>=10.14.0->streamlit) (2.19.1)
# Collecting markdown-it-py>=2.2.0
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in ./myenv/lib/python3.8/site-packages (from astunparse>=1.6.0->tensorflow-macos==2.13.0->tensorflow) (0.45.1)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in ./myenv/lib/python3.8/site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.5)
# Collecting referencing>=0.28.4
#   Downloading referencing-0.35.1-py3-none-any.whl (26 kB)
# Collecting attrs>=22.2.0
#   Downloading attrs-25.3.0-py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.8/63.8 kB 7.7 MB/s eta 0:00:00
# Requirement already satisfied: importlib-resources>=1.4.0 in ./myenv/lib/python3.8/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (6.4.5)
# Collecting rpds-py>=0.7.1
#   Downloading rpds_py-0.20.1-cp38-cp38-macosx_11_0_arm64.whl (318 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.8/318.8 kB 8.5 MB/s eta 0:00:00
# Collecting jsonschema-specifications>=2023.03.6
#   Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Collecting pkgutil-resolve-name>=1.3.10
#   Downloading pkgutil_resolve_name-1.3.10-py3-none-any.whl (4.7 kB)
# Collecting mdurl~=0.1
#   Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: google-auth<3,>=1.6.3 in ./myenv/lib/python3.8/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (2.38.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in ./myenv/lib/python3.8/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in ./myenv/lib/python3.8/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (3.7)
# Requirement already satisfied: werkzeug>=1.0.1 in ./myenv/lib/python3.8/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (3.0.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./myenv/lib/python3.8/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (0.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./myenv/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./myenv/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in ./myenv/lib/python3.8/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (2.0.0)
# Requirement already satisfied: zipp>=3.1.0 in ./myenv/lib/python3.8/site-packages (from importlib-resources>=1.4.0->jsonschema>=3.0->altair<6,>=4.0->streamlit) (3.20.2)
# Requirement already satisfied: importlib-metadata>=4.4 in ./myenv/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (8.5.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in ./myenv/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in ./myenv/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (3.2.2)
# Installing collected packages: pytz, tzdata, toolz, toml, tenacity, smmap, rpds-py, pyarrow, pkgutil-resolve-name, mdurl, jinja2, click, blinker, attrs, referencing, pydeck, pandas, markdown-it-py, gitdb, rich, jsonschema-specifications, gitpython, jsonschema, altair, streamlit
# Successfully installed altair-5.3.0 attrs-25.3.0 blinker-1.8.2 click-8.1.8 gitdb-4.0.12 gitpython-3.1.44 jinja2-3.1.6 jsonschema-4.23.0 jsonschema-specifications-2023.12.1 markdown-it-py-3.0.0 mdurl-0.1.2 pandas-2.0.3 pkgutil-resolve-name-1.3.10 pyarrow-17.0.0 pydeck-0.9.1 pytz-2025.1 referencing-0.35.1 rich-13.9.4 rpds-py-0.20.1 smmap-5.0.2 streamlit-1.40.1 tenacity-9.0.0 toml-0.10.2 toolz-1.0.0 tzdata-2025.1
# WARNING: There was an error checking the latest version of pip.
# 2025-03-16 21:27:55.550 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-16 21:27:55.762
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /Users/girish/Desktop/development/Multi Cancer Detection/myenv/lib/python3.8/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2025-03-16 21:27:55.762 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-16 21:27:55.763 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-16 21:27:56.270 Thread 'Thread-4': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-16 21:27:56.270 Thread 'Thread-4': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-16 21:27:56.419 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-16 21:27:56.419 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-16 21:27:56.419 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-16 21:27:56.420 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-16 21:27:56.420 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-16 21:27:56.420 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-16 21:27:56.420 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-16 21:27:56.421 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-16 21:27:56.421 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-16 21:27:56.421 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-16 21:27:56.421 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-16 21:27:56.421 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-16 21:27:56.422 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
